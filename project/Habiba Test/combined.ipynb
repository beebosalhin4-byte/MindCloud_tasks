# %%
import joblib
import os
import numpy as np
import pandas as pd
import soundfile as sf
import processing as p
import Features2 as f
from scipy.io.wavfile import write

# %%
# Listen for a maximum of 5 minutes (300 seconds) before stopping automatically
input_file = p.go(timeout_seconds=300)

if input_file is None:
    print("No audio was caught during the listening period.")
else:
    # Run your saving and feature extraction steps here
    print("Audio captured successfully!")

temp_path = "temp_live_audio.wav"
write(temp_path, 22050, input_file)
print("Done!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 input_file = p.go()
#       2 temp_path = "temp_live_audio.wav"
#       3 write(temp_path, 22050, input_file)
#       4 print("Done!")
#
# File ~/mindcloud/project/Habiba Test/processing.py:91, in go()
#      90 def go():
# ---> 91     while not is_cry_detected():
#      92         print("No noise detected")
#      93         time.sleep(0.01)
#
# File ~/mindcloud/project/Habiba Test/processing.py:81, in is_cry_detected(duration, sr)
#      79 t0 = time.time()
#      80 raw_audio = sd.rec(int(duration * sr), samplerate=sr, channels=1, dtype='float32')
# ---> 81 sd.wait()  # Hardware blocking pause for audio capture
#      82 raw_audio = np.squeeze(raw_audio)
#      83 pcm_bytes = (raw_audio * 32767).astype(np.int16).tobytes()
#
# File ~/.venv/lib/python3.14/site-packages/sounddevice.py:404, in wait(ignore_errors)
#     388 """Wait for `play()`/`rec()`/`playrec()` to be finished.
#     389
#     390 Playback/recording can be stopped with a `KeyboardInterrupt`.
#    (...)    401
#     402 """
#     403 if _last_callback:
# --> 404     return _last_callback.wait(ignore_errors)
#
# File ~/.venv/lib/python3.14/site-packages/sounddevice.py:2684, in _CallbackContext.wait(self, ignore_errors)
#    2678 """Wait for finished_callback.
#    2679
#    2680 Can be interrupted with a KeyboardInterrupt.
#    2681
#    2682 """
#    2683 try:
# -> 2684     self.event.wait()
#    2685 finally:
#    2686     self.stream.close(ignore_errors)
#
# File /usr/lib/python3.14/threading.py:670, in Event.wait(self, timeout)
#     668 signaled = self._flag
#     669 if not signaled:
# --> 670     signaled = self._cond.wait(timeout)
#     671 return signaled
#
# File /usr/lib/python3.14/threading.py:369, in Condition.wait(self, timeout)
#     367 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     368     if timeout is None:
# --> 369         waiter.acquire()
#     370         gotit = True
#     371     else:
#
# KeyboardInterrupt:

# %%
output_list= []
f.featureextraction(temp_path,output_list)
output_df=pd.DataFrame(output_list)
single_input = output_df.loc[:, "f0_mean":]

# %%
loaded_model = joblib.load('my_ml_model.joblib')
prediction = loaded_model.predict(single_input)
output_list= []
print(f"The model prediction for this file is: {prediction[0]}")
